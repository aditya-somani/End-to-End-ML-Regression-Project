# %%
import pandas as pd
from category_encoders import TargetEncoder

# 1. Load cleaned datasets
train_df = pd.read_csv(r'C:\Users\H.P\Desktop\Housing Regression MLE\data\processed\train_cleaned.csv')
eval_df = pd.read_csv(r'C:\Users\H.P\Desktop\Housing Regression MLE\data\processed\eval_cleaned.csv')
holdout_df = pd.read_csv(r'C:\Users\H.P\Desktop\Housing Regression MLE\data\processed\holdout_cleaned.csv')

pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows

print("Train date range:", train_df["date"].min(), "to", train_df["date"].max())
print("Eval date range:", eval_df["date"].min(), "to", eval_df["date"].max())
print("Holdout date range:", holdout_df["date"].min(), "to", holdout_df["date"].max())

# Ensure datetime
train_df["date"] = pd.to_datetime(train_df["date"])
eval_df["date"] = pd.to_datetime(eval_df["date"])
holdout_df["date"] = pd.to_datetime(holdout_df["date"])
# Out:
# Train date range: 2012-03-31 to 2019-12-31
# Eval date range: 2020-01-31 to 2021-12-31
# Holdout date range: 2022-01-31 to 2023-12-31
